# %% [markdown]
# <a href="https://colab.research.google.com/github/shubh37975/Data-_Science_Lab/blob/master/Practical_No_1(ii).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

print(f"Multiplication Table for {num}:")
for i in range(1, 11):
   print(f"{num} x {i} = {num * i}")
