# %% [markdown]
# <a href="https://colab.research.google.com/github/shubh37975/Data-_Science_Lab/blob/master/Practical_No_1(iii).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Get input from the user
number = int(input("Enter a number: "))

# Check if the number is odd or even
if (number % 2) == 0:
   print(f"{number} is an Even number")
else:
   print(f"{number} is an Odd number")
